# %%
# !pip install opendatasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import opendatasets as od

# %%
dataset = 'https://www.kaggle.com/datasets/brendan45774/countries-life-expectancy'

# %%
od.download(dataset)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: elamathiramesh
# Your Kaggle Key: ········
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 17.2k/17.2k [00:00<00:00, 493kB/s]

# %%
import os

# %%
data_dir = '.\countries-life-expectancy'

# %%
os.listdir(data_dir)
# Out:
# ['Life expectancy.csv']

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
life_df = pd.read_csv('Life expectancy.csv')
life_df
# Out:
#              Entity  Year  Life expectancy
# 0         Australia  1802        34.049999
# 1         Australia  1803        34.049999
# 2         Australia  1804        34.049999
# 3         Australia  1805        34.049999
# 4         Australia  1806        34.049999
# ...             ...   ...              ...
# 3248  United States  2012        78.940002
# 3249  United States  2013        78.959999
# 3250  United States  2014        78.940002
# 3251  United States  2015        78.870003
# 3252  United States  2016        78.860001
#
# [3253 rows x 3 columns]

# %%
#1 understanding the data

# %%
life_df.head()
# Out:
#       Entity  Year  Life expectancy
# 0  Australia  1802        34.049999
# 1  Australia  1803        34.049999
# 2  Australia  1804        34.049999
# 3  Australia  1805        34.049999
# 4  Australia  1806        34.049999

# %%
life_df.shape
# Out:
# (3253, 3)

# %%
life_df.describe()
# Out:
#               Year  Life expectancy
# count  3253.000000      3253.000000
# mean   1908.066093        48.680380
# std      62.613962        17.965669
# min    1800.000000         8.108836
# 25%    1854.000000        32.000000
# 50%    1908.000000        41.880001
# 75%    1962.000000        66.820000
# max    2016.000000        83.940002

# %%
life_df.columns
# Out:
# Index(['Entity', 'Year', 'Life expectancy'], dtype='object')

# %%
life_df.nunique()
# Out:
# Entity               15
# Year                217
# Life expectancy    2190
# dtype: int64

# %%
life_df['Entity'].unique()
# Out:
# array(['Australia', 'Brazil', 'Canada', 'China', 'France', 'Germany',
#        'India', 'Italy', 'Japan', 'Mexico', 'Russia', 'Spain',
#        'Switzerland', 'United Kingdom', 'United States'], dtype=object)

# %%
#cleaning the data

# %%
life_df.isnull().sum()
# Out:
# Entity             0
# Year               0
# Life expectancy    0
# dtype: int64

# %%
#3 relationship analysis

# %%
corelation = life_df.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(life_df)

# %%
sns.relplot(x='Entity',y='Life expectancy',data=life_df)

# %%
sns.displot(life_df['Life expectancy'])

# %%
sns.catplot(x='Life expectancy',kind='box',data=life_df)
